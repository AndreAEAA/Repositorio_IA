# %% [markdown]
# <a href="https://colab.research.google.com/github/AndreAEAA/Repositorio_IA/blob/main/TAREA1_1_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ejercicio 1
#Cree un programa que reciba una lista de números y devuelva el número mayor sin usar la función max()

def numero_mayor(lista):
    if not lista:
        return None
    mayor = lista[0]
    for numero in lista:
        if numero > mayor:
            mayor = numero
    return mayor

# Ejemplo de uso
numeros = [20,]
print("El número mayor es:", numero_mayor(numeros))
# Out:
# El número mayor es: 20

# %%
#Ejercicio 2
#Escriba un programa que solicite un número al usuario y
 #muestre la tabla de multiplicar del 1 al 10 de ese número.
n = int(input("Ingrese el número: "))

print(f"\n La de multiplicar del {n}:")
for i in range(1, 13):
    resultado = n * i
    print(f"{n} x {i} = {resultado}")
# Out:
# Ingrese el número: 8
#
#  La de multiplicar del 8:
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80
# 8 x 11 = 88
# 8 x 12 = 96

# %%
#Ejercicio 3 Cree un programa que elimine los elementos repetidos de una lista y devuelva una nueva lista con elementos únicos ordenados.

def eliminar (lista):
    lista_unica = []
    for elemento in lista:
        if elemento not in lista_unica:
            lista_unica.append(elemento)
    return sorted(lista_unica)

# Ejemplo de uso
lista = [5, 2, 9, 5, 1, 2, 8, 9]
resultado = eliminar (lista)
print("Lista sin repetidos y ordenada:", resultado)
# Out:
# Lista sin repetidos y ordenada: [1, 2, 5, 8, 9]

# %%
 #Ejercicio 4 Escriba un programa que solicite ingresar el nombre de varios
# estudiantes y su nota, y lo almacene en un diccionario. Al final, muestra los datos almacenados.


estudiantes = {}

while True:
    nombre = input("Ingresa el nombre del estudiante (o escribe 'fin' para terminar): ")
    if nombre.lower() == 'fin':
        break
    try:
        nota = float(input(f"Ingrese la nota de {nombre}: "))
        estudiantes[nombre] = nota
    except ValueError:
        print("Por favor, ingresa una nota válida (número).")

print("\nDatos de los estudiantes:")
for nombre, nota in estudiantes.items():
    print(f"{nombre}: {nota}")
# Out:
# Ingresa el nombre del estudiante (o escribe 'fin' para terminar): kenia}
# Ingrese la nota de kenia}: 89
# Ingresa el nombre del estudiante (o escribe 'fin' para terminar): camilo
# Ingrese la nota de camilo: 99
# Ingresa el nombre del estudiante (o escribe 'fin' para terminar): fin
#
# Datos de los estudiantes:
# kenia}: 89.0
# camilo: 99.0

# %%
#Ejercicio 5
ventas = {
    'Producto': ['A', 'B', 'A', 'C', 'B', 'A'],
    'Cantidad': [10, 5, 7, 3, 2, 8]
}

suma = {}

for a in range(len(ventas['Producto'])):
    producto = ventas['Producto'][a]
    cantidad = ventas['Cantidad'][a]
    if producto in suma:
        suma[producto] += cantidad
    else:
        suma[producto] = cantidad

print("\n Venta total:")
print(suma)
# Out:
#  Venta total:
# {'A': 25, 'B': 7, 'C': 3}
